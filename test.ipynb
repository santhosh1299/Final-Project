# %%
import pandas as pd
import numpy as np

# %%
df  = pd.read_csv("h.csv")

df
# Out:
#          Rooms  Distance  Bedroom2      Bathroom           Car   Landsize  \
# 0     1.386295  2.014903  1.386295  6.931477e-01  6.931477e-01   6.641182
# 1     0.693148  1.704748  0.693148  9.999995e-07  9.999995e-07   5.241747
# 2     1.098613  2.219204  1.098613  9.999995e-07  1.386295e+00   6.405228
# 3     1.098613  1.648659  1.098613  9.999995e-07  9.999995e-07   5.780744
# 4     1.386295  2.624669  1.386295  1.098613e+00  6.931477e-01   6.590301
# ...        ...       ...       ...           ...           ...        ...
# 5427  1.098613  2.415914  1.098613  9.999995e-07  9.999995e-07 -13.815511
# 5428  0.693148  1.280934  0.693148  9.999995e-07  9.999995e-07   5.099866
# 5429  1.098613  0.955512  1.098613  9.999995e-07  9.999995e-07   5.948035
# 5430  0.693148  2.631889  0.693148  6.931477e-01  9.999995e-07   5.303305
# 5431  1.098613  2.104134  1.098613  9.999995e-07  6.931477e-01   6.216606
#
#       BuildingArea  Propertycount      Price
# ...

# %%
# Check for infinite values
inf_values = df.isin([np.inf, -np.inf])

# Display rows with infinite values
print("Rows with infinite values:")
print(df[inf_values.any(axis=1)])

# Display columns with infinite values
print("Columns with infinite values:")
print(df.columns[inf_values.any()])
# Out:
# Rows with infinite values:
# Empty DataFrame
# Columns: [Rooms, Distance, Bedroom2, Bathroom, Car, Landsize, BuildingArea, Propertycount, Price]
# Index: []
# Columns with infinite values:
# Index([], dtype='object')
